# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
akshaypawar7_millions_of_movies_path = kagglehub.dataset_download('akshaypawar7/millions-of-movies')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/akshaypawar7/millions-of-movies?dataset_version_number=911...
# 100%|██████████| 164M/164M [00:01<00:00, 138MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# ## Import Libraries

# %%
pip install catboost xgboost lightgbm shap seaborn
# Out:
# Collecting catboost
#   Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.11/dist-packages (2.1.4)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.11/dist-packages (4.5.0)
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.47.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.15.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.11/dist-packages (from xgboost) (2.21.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from shap) (1.6.1)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (2.9.0.post0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.1.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->shap) (3.6.0)
# Downloading catboost-1.2.8-cp311-cp311-manylinux2014_x86_64.whl (99.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 8.2 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.8

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr
import re
from datetime import datetime
from IPython.display import display
from collections import defaultdict
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

from sklearn.model_selection import train_test_split

from scipy.stats import pearsonr
import math
from statistics import median
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, ExtraTreesRegressor
from catboost import CatBoostRegressor
import xgboost as xgb
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error, accuracy_score
import shap

# %matplotlib inline

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv(akshaypawar7_millions_of_movies_path + "/movies.csv")
df.head()
# Out:
#        id                             title                            genres  \
# 0  615656                 Meg 2: The Trench     Action-Science Fiction-Horror
# 1  758323               The Pope's Exorcist           Horror-Mystery-Thriller
# 2  533535              Deadpool & Wolverine     Action-Comedy-Science Fiction
# 3  667538  Transformers: Rise of the Beasts  Action-Adventure-Science Fiction
# 4  693134                    Dune: Part Two         Science Fiction-Adventure
#
#   original_language                                           overview  \
# 0                en  An exploratory dive into the deepest depths of...
# 1                en  Father Gabriele Amorth Chief Exorcist of the V...
# 2                en  A listless Wade Wilson toils away in civilian ...
# 3                en  When a new threat capable of destroying the en...
# 4                en  Follow the mythic journey of Paul Atreides as ...
#
#    popularity                               production_companies release_date  \
# 0    8763.998  Apelles Entertainment-Warner Bros. Pictures-di...   2023-08-02
# 1    5953.227  Screen Gems-2.0 Entertainment-Jesus & Mary-Wor...   2023-04-05
# 2    5410.496  Marvel Studios-Maximum Effort-21 Laps Entertai...   2024-07-24
# 3    5409.104  Skydance-Paramount-di Bonaventura Pictures-Bay...   2023-06-06
# 4    4742.163                                 Legendary Pictures   2024-02-27
#
#         budget       revenue  runtime    status  \
# 0  129000000.0  3.520565e+08    116.0  Released
# 1   18000000.0  6.567582e+07    103.0  Released
# 2  200000000.0  1.326387e+09    128.0  Released
# 3  200000000.0  4.070455e+08    127.0  Released
# 4  190000000.0  6.838137e+08    167.0  Released
#
#                                              tagline  vote_average  \
# 0                                  Back for seconds.         7.079
# 1  Inspired by the actual files of Father Gabriel...         7.433
# 2                                     Come together.         7.765
# 3                                     Unite or fall.         7.340
# 4                            Long live the fighters.         8.300
#
#    vote_count                                            credits  \
# 0      1365.0  Jason Statham-Wu Jing-Shuya Sophia Cai-Sergio ...
# 1       545.0  Russell Crowe-Daniel Zovatto-Alex Essoe-Franco...
# 2      3749.0  Ryan Reynolds-Hugh Jackman-Emma Corrin-Matthew...
# 3      1007.0  Anthony Ramos-Dominique Fishback-Luna Lauren V...
# 4      2770.0  Timothée Chalamet-Zendaya-Rebecca Ferguson-Jav...
#
#                                             keywords  \
# 0                based on novel or book-sequel-kaiju
# 1  spain-rome italy-vatican-pope-pig-possession-c...
# 2  hero-superhero-anti hero-mutant-breaking the f...
# 3  peru-alien-end of the world-based on cartoon-b...
# 4  epic-based on novel or book-fight-sandstorm-sa...
#
#                         poster_path                     backdrop_path  \
# 0  /4m1Au3YkjqsxF8iwQy0fPYSxE0h.jpg  /qlxy8yo5bcgUw2KAmmojUKp4rHd.jpg
# 1  /9JBEPLTPSm0d1mbEcLxULjJq9Eh.jpg  /hiHGRbyTcbZoLsYYkO4QiCLYe34.jpg
# 2  /8cdWjvZQUExUUTzyp4t6EDMubfO.jpg  /dvBCdCohwWbsP5qAaglOXagDMtk.jpg
# 3  /gPbM0MK8CP8A174rmUwGsADNYKD.jpg  /woJbg7ZqidhpvqFGGMRhWQNoxwa.jpg
# 4  /czembW0Rk1Ke7lCJGahbOhdCuhV.jpg  /xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg
#
#                                      recommendations
# 0  1006462-298618-569094-1061181-346698-1076487-6...
# 1  713704-296271-502356-1076605-1084225-1008005-9...
# 2  573435-519182-957452-1022789-945961-718821-103...
# 3  496450-569094-298618-385687-877100-598331-4628...
# 4  438631-763215-792307-1011985-467244-634492-359...

# %% [markdown]
# ## Data Understanding, Removing Outliers & Unreleased Movies

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722317 entries, 0 to 722316
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    722317 non-null  int64
#  1   title                 722311 non-null  object
#  2   genres                512000 non-null  object
#  3   original_language     722317 non-null  object
#  4   overview              604074 non-null  object
#  5   popularity            722317 non-null  float64
#  6   production_companies  337391 non-null  object
#  7   release_date          670768 non-null  object
#  8   budget                722317 non-null  float64
#  9   revenue               722317 non-null  float64
#  10  runtime               687982 non-null  float64
#  11  status                722317 non-null  object
#  12  tagline               108476 non-null  object
#  13  vote_average          722317 non-null  float64
#  14  vote_count            722317 non-null  float64
#  15  credits               497603 non-null  object
#  16  keywords              210639 non-null  object
#  17  poster_path           537824 non-null  object
#  18  backdrop_path         223211 non-null  object
#  19  recommendations       36016 non-null   object
# dtypes: float64(6), int64(1), object(13)
# memory usage: 110.2+ MB

# %%
df.shape
# Out:
# (722317, 20)

# %%
df.describe()
# Out:
#                   id     popularity        budget       revenue       runtime  \
# count  722317.000000  722317.000000  7.223170e+05  7.223170e+05  6.879820e+05
# mean   526920.121246       1.918179  4.043453e+05  1.007747e+06  1.990905e+02
# std    253200.153542      23.692240  8.242868e+06  2.048321e+07  8.584257e+04
# min         2.000000       0.000000  0.000000e+00 -1.200000e+01  0.000000e+00
# 25%    328914.000000       0.600000  0.000000e+00  0.000000e+00  5.000000e+00
# 50%    533351.000000       0.600000  0.000000e+00  0.000000e+00  5.000000e+01
# 75%    737872.000000       1.303000  0.000000e+00  0.000000e+00  9.000000e+01
# max    968161.000000    8763.998000  5.000000e+09  2.920357e+09  5.050505e+07
#
#         vote_average     vote_count
# count  722317.000000  722317.000000
# mean        2.446389      28.484715
# std         3.176491     396.575042
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         5.600000       2.000000
# max        10.000000   34857.000000

# %% [markdown]
# By using the describe function, we obtain a comprehensive overview of the data. The output includes statistics such as count, mean, standard deviation, minimum and maximum values, as well as quartiles. These descriptive statistics help us understand the distribution, central tendency, and variability of the data, enabling us to gain insights into the movies' popularity, financial aspects (budget and revenue), duration (runtime), and audience ratings (vote average and count).
#
# The dataset contains outliers where the budget and revenue values are recorded as 0 until around the 50th percentile, as well as instances where the runtime is recorded as 0. To prevent these outliers from affecting data analysis and modeling, it might be better to remove them later, as they likely represent errors or missing information. This will result in a cleaner dataset, leading to more accurate and reliable statistical analysis and decision-making.

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
def nans(df): return df[df.isnull().any(axis=1)]
nans(df)
# Out:
#             id                         title  \
# 13      956101             The Eighth Clause
# 14      572802  Aquaman and the Lost Kingdom
# 18      753342                      Napoleon
# 21      968051                    The Nun II
# 22      965839           Lord of the Streets
# ...        ...                           ...
# 722312  836042                  Tomcat Tales
# 722313  527223               Strictly Modern
# 722314  717787                   Your Letter
# 722315  718477        Café Tacvba - Un Viaje
# 722316  414194                Wild Playgirls
#
#                                    genres original_language  \
# 13                               Thriller                la
# 14               Action-Adventure-Fantasy                en
# 18                      History-War-Drama                en
# 21                Horror-Mystery-Thriller                en
# 22                                 Action                en
# ...                                   ...               ...
# 722312            Documentary-History-War                en
# 722313                     Comedy-Romance                en
# 722314  Animation-Drama-Mystery-Adventure                ko
# 722315                                NaN                en
# 722316                                NaN                fr
#
#                                                  overview  popularity  \
# 13      Kat and Borja appear to be a perfect couple bu...    2259.303
# 14      Black Manta still driven by the need to avenge...    2141.691
# 18      An epic that details the checkered rise and fa...    1811.360
# 21      In 1956 France a priest is violently murdered ...    1696.620
# 22      When Jason Dyson refuses to make his prized fi...    1691.825
# ...                                                   ...         ...
# 722312  Learn from real-life Top Guns who have flown a...       0.001
# 722313  Strictly Modern is a 1930 American pre-Code co...       0.001
# 722314  Sori Lee is hoping for a fresh start at her ne...       0.001
# 722315  Un Viaje is the first live album by the rock b...       0.001
# 722316  Two men who have the financial problems decide...       0.000
#
#                                      production_companies release_date  \
# 13                           SDB Films-El Hombre Orquesta   2022-04-29
# 14      Warner Bros. Pictures-The Safran Company-Atomi...   2023-12-20
# 18      Scott Free Productions-Latina Pictures-Apple S...   2023-11-22
# 21      New Line Cinema-Atomic Monster-The Safran Company   2023-09-06
# 22                                           Mutiny Films   2022-04-22
# ...                                                   ...          ...
# 722312                                                NaN   2020-01-01
# 722313  First National Pictures-Warner Bros. Entertain...   1930-03-02
# 722314                                           Studio N   2024-09-27
# 722315                                                NaN   2005-04-19
# 722316                                Ribu Filmproduktion   1981-05-20
#
#              budget      revenue  runtime    status  \
# 13              0.0          0.0      0.0  Released
# 14      205000000.0  397860076.0    124.0  Released
# 18      165000000.0  213400000.0    158.0  Released
# 21       38500000.0  257010000.0    110.0  Released
# 22        1000000.0          0.0     85.0  Released
# ...             ...          ...      ...       ...
# 722312          0.0          0.0    120.0  Released
# 722313          0.0          0.0     63.0  Released
# 722314          0.0          0.0     97.0  Released
# 722315          0.0          0.0    120.0  Released
# 722316          0.0          0.0     84.0  Released
#
#                                                   tagline  vote_average  \
# 13                                                    NaN         4.600
# 14                                   The tide is turning.         6.786
# 18         He came from nothing. He conquered everything.         6.516
# 21                                     Confess your sins.         7.004
# 22                                                    NaN         4.900
# ...                                                   ...           ...
# 722312                                                NaN         0.000
# 722313  Dorothy MACKAILL -THE WOMAN who thought she kn...         0.000
# 722314                                                NaN         0.000
# 722315                                                NaN         0.000
# 722316                                                NaN         7.400
#
#         vote_count                                            credits  \
# 13            10.0  Maite Perroni-Manuel Vega-Óscar Jaenada-Jessic...
# 14           756.0  Patrick Wilson-Yahya Abdul-Mateen II-Randall P...
# 18          1282.0  Joaquin Phoenix-Vanessa Kirby-Rupert Everett-M...
# 21          1073.0  Taissa Farmiga-Jonas Bloquet-Storm Reid-Anna P...
# 22            29.0  Treach-Quinton Jackson-Khalil Rountree Jr.-And...
# ...            ...                                                ...
# 722312         0.0                                                NaN
# 722313         0.0  Dorothy Mackaill-Sidney Blackmer-Julanne Johns...
# 722314         0.0  Lee Soo-hyun-Kim Min-ju-Min Seungwoo-Nam Doh-h...
# 722315         0.0  Rubén Albarrán-Emmanuel del Real-Joselo Rangel...
# 722316         5.0  Richard Lemieuvre-Alban Ceray-Uschi Karnat-Dor...
#
#                                                  keywords  \
# 13                                                    NaN
# 14      superhero-secret society-half-brother-sequel-r...
# 18      empire-france-biography-napoleon bonaparte-bas...
# 21      france-bullying-sequel-religion-demon-gothic h...
# 22                                                    NaN
# ...                                                   ...
# 722312                                                NaN
# 722313                                          lost film
# 722314                 bullying-slice of life-school life
# 722315                                                NaN
# 722316            brothel-male prostitution-street walker
#
#                              poster_path                     backdrop_path  \
# 13      /8tc8eMFAX2SDC1TRu987qFQy8Cl.jpg  /kLnqNE9Af5QHyvUxw8cDGhF1ilv.jpg
# 14      /7lTnXOy0iNtBAdRP3TZvaKJ77F6.jpg  /jXJxMcVoEuXzym3vFnjqDW4ifo6.jpg
# 18      /jE5o7y9K6pZtWNNMEw3IdpHuncR.jpg  /f1AQhx6ZfGhPZFTVKgxG91PhEYc.jpg
# 21      /5gzzkR7y3hnY8AD1wXjCnVlHba5.jpg  /53z2fXEKfnNg2uSOPss2unPBGX1.jpg
# 22      /n9YWVQRc0zw0nwrFcOkOpffZxjc.jpg  /g8Yytnby0hIPft5l56mgJtZyR1k.jpg
# ...                                  ...                               ...
# 722312  /8mkAUkkRCLvMBMBvLFvhLF9SPC4.jpg                               NaN
# 722313  /qr4dU5DOhOJ3YTBdpdXpG6AUOyZ.jpg                               NaN
# 722314                               NaN  /thsAU92Ei2Nbm38ZdkvHI8xLaSc.jpg
# 722315  /95HgsWBDuSJBgcq0Fkv4JYZeTdR.jpg  /laiCThOhK5LKJJsMSXSzoePv8uX.jpg
# 722316  /udhVUBPcF3IpHM7WD5m82r9t2SC.jpg                               NaN
#
#                                           recommendations
# 13                                                    NaN
# 14                                                    NaN
# 18                                                    NaN
# 21                                                    NaN
# 22                                                 982467
# ...                                                   ...
# 722312                                                NaN
# 722313                                                NaN
# 722314                                                NaN
# 722315                                                NaN
# 722316  28648-29514-10937-8217-4483-35626-11285-24939-...
#
# [707525 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 722317 entries, 0 to 722316
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    722317 non-null  int64
#  1   title                 722311 non-null  object
#  2   genres                512000 non-null  object
#  3   original_language     722317 non-null  object
#  4   overview              604074 non-null  object
#  5   popularity            722317 non-null  float64
#  6   production_companies  337391 non-null  object
#  7   release_date          670768 non-null  object
#  8   budget                722317 non-null  float64
#  9   revenue               722317 non-null  float64
#  10  runtime               687982 non-null  float64
#  11  status                722317 non-null  object
#  12  tagline               108476 non-null  object
#  13  vote_average          722317 non-null  float64
#  14  vote_count            722317 non-null  float64
#  15  credits               497603 non-null  object
#  16  keywords              210639 non-null  object
#  17  poster_path           537824 non-null  object
#  18  backdrop_path         223211 non-null  object
#  19  recommendations       36016 non-null   object
# dtypes: float64(6), int64(1), object(13)
# memory usage: 110.2+ MB

# %%
print ('The data has {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# The data has 722317 rows and 20 columns

# %% [markdown]
# Given the extensive size of the dataset, it becomes imperative to implement techniques that can reduce the data size or limit the information being processed. This reduction in data will help alleviate the burden on the RAM, which has a finite capacity for storing and manipulating data.

# %% [markdown]
# In order to eliminate duplicate rows in a dataframe, the entries with identical IDs will be discarded, retaining only the first occurrence. This process ensures that the resulting dataframe contains unique records based on their IDs. By removing duplicates and preserving the original order, we maintain the integrity of the dataset.

# %%
df = df.drop_duplicates(subset='id', keep='first')
print ('Currently, the data has {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# Currently, the data has 662083 rows and 20 columns

# %% [markdown]
# We will also remove all movies that have not been released yet from our dataset. This is because the target variable we are interested in predicting, which is the revenue, cannot be known for movies that have not yet hit the theaters or been made available to the public. Therefore, including unreleased movies would introduce bias and potentially skew our analysis and predictions.

# %%
df = df[df['status'] == 'Released']
print ('Currently, the data has {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# Currently, the data has 657261 rows and 20 columns

# %% [markdown]
# As we have already excluded unreleased movies from our dataset, the 'status' column does not offer any valuable variation or insights for our analysis. Since the 'status' column only contains a single potential value, namely 'released', removing it will streamline our dataset and remove extraneous data that does not contribute to our predictive modeling.

# %%
df = df.drop('status', axis=1)

# %% [markdown]
# We will also remove the movies which have no release date.

# %%
df.dropna(subset=['release_date'], inplace=True)

# %%
df = df[df['release_date'].notna()]

# %%
df['release_date'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# The decision was made to condense the dataset by only including movies with a release date of at least the 2000s. This choice was driven by the need to focus on a more contemporary and relevant collection of films, excluding older titles that may have less relevance to current audiences. By limiting the dataset to movies released from the 2000s onwards, a more streamlined and targeted dataset can be obtained, facilitating analysis and research specific to the modern era of cinema.

# %%
df = df[df['release_date'] >= '1900']
print ('Currently, the data has {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# Currently, the data has 609954 rows and 19 columns

# %%
df = df[df.revenue > 0]
print ('Currently, the data has {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# Currently, the data has 16033 rows and 19 columns

# %%
print("Dataset missing values:\n", df.isna().sum())
# Out:
# Dataset missing values:
#  id                         0
# title                      0
# genres                   262
# original_language          0
# overview                 472
# popularity                 0
# production_companies    1256
# release_date               0
# budget                     0
# revenue                    0
# runtime                   50
# tagline                 5009
# vote_average               0
# vote_count                 0
# credits                  245
# keywords                2764
# poster_path              368
# backdrop_path           1858
# recommendations         6161
# dtype: int64

# %%
# Loại bỏ phim có revenue hoặc popularity bằng 0
df = df[df['revenue'] > 0]
df = df[df['popularity'] > 0]
# Loại bỏ phim có budget hoặc runtime bằng 0
df = df[df['budget'] > 0]
df = df[df['runtime'] > 0]
print ('Currently, the data has {} rows and {} columns'.format(df.shape[0],df.shape[1]))
# Out:
# Currently, the data has 10189 rows and 19 columns

# %%
# Xử lý giá trị thiếu
df['vote_average'] = df['vote_average'].fillna(df['vote_average'].mean())
df['vote_count'] = df['vote_count'].fillna(df['vote_count'].median())
df['genres'] = df['genres'].fillna('Unknown')
df['production_companies'] = df['production_companies'].fillna('Unknown')

# %%
# Xử lý giá trị ngoại lai bằng IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
    return df

for col in ['budget', 'revenue', 'popularity', 'runtime', 'vote_average', 'vote_count']:
    df = remove_outliers(df, col)

# %%
# Chuẩn hóa dữ liệu số
scaler = MinMaxScaler()
numeric_columns = ['budget', 'revenue', 'popularity', 'runtime', 'vote_average', 'vote_count']
df[numeric_columns] = scaler.fit_transform(df[numeric_columns])

# %%
# Kiểm tra lại dữ liệu
print("Final dataset shape:", df.shape)
print("Final missing values:\n", df.isna().sum())
print(df.head())
# Out:
# Final dataset shape: (5895, 19)
# Final missing values:
#  id                         0
# title                      0
# genres                     0
# original_language          0
# overview                  14
# popularity                 0
# production_companies       0
# release_date               0
# budget                     0
# revenue                    0
# runtime                    0
# tagline                 1355
# vote_average               0
# vote_count                 0
# credits                   11
# keywords                 653
# poster_path               22
# backdrop_path            267
# recommendations         1772
# dtype: int64
#           id                               title  \
# 2624   21972                           Like Mike
# 2627    1687  Escape from the Planet of the Apes
# 2639  734002                        The Peasants
# 2644   11212                      Baby's Day Out
# 2652   59429    Paranormal Activity: Tokyo Night
#
#                                    genres original_language  \
# 2624                Family-Comedy-Fantasy                en
# 2627               Action-Science Fiction                en
# 2639                        Drama-History                pl
# 2644  Family-Comedy-Adventure-Crime-Drama                en
# 2652                      Horror-Thriller                ja
#
#                                                overview  popularity  \
# 2624  Calvin and his friends who all live in an orph...    1.000000
# 2627  The world is shocked by the appearance of thre...    0.999912
# 2639  Peasant girl Jagna is forced to marry the much...    0.996262
# 2644  Baby Bink couldn't ask for more: he has adorin...    0.994202
# 2652  Koichi takes care of his sister who has recent...    0.992171
#
#                                    production_companies release_date  \
# 2624  20th Century Fox-Heller Highwater Productions-...   2002-07-03
# 2627                 APJAC Productions-20th Century Fox   1971-05-20
# 2639  Breakthru Films-ArtShot-DigitalKraft-Canal+ Po...   2023-10-13
# 2644              20th Century Fox-Hughes Entertainment   1994-07-01
# 2652    IM Global-Cinema Sunshine-Presidio-Musashino Ad   2010-11-20
#
#         budget   revenue   runtime  \
# 2624  0.447761  0.655650  0.456311
# 2627  0.037313  0.130499  0.446602
# 2639  0.111567  0.103253  0.611650
# 2644  0.746269  0.175452  0.456311
# 2652  0.020149  0.043780  0.378641
#
#                                                 tagline  vote_average  \
# 2624  Think like Mike, Achieve like Mike, Be Like Mike.      0.469388
# 2627       Meet baby Milo who has Washington terrified.      0.510204
# 2639                Love comes and goes but land stays.      0.816327
# 2644                       No Bib. No Crib. No Problem.      0.510204
# 2652                          The nightmare continue...      0.448980
#
#       vote_count                                            credits  \
# 2624    0.272977  Shad Moss-Morris Chestnut-Jonathan Lipnicki-Br...
# 2627    0.506329  Roddy McDowall-Kim Hunter-Bradford Dillman-Nat...
# 2639    0.047881  Kamila Urzędowska-Robert Gulaczyk-Mirosław Bak...
# 2644    0.611447  Joe Mantegna-Lara Flynn Boyle-Joe Pantoliano-B...
# 2652    0.204183  Aoi Nakamura-Noriko Aoyama-Kosuke Kujirai-Ayak...
#
#                                                keywords  \
# 2624  bet-lightning-sports-orphanage-bullying-basket...
# 2627  spacecraft-dystopia-pacifism-politician-sequel...
# 2639  adultery-based on novel or book-peasant-nobel ...
# 2644  chicago illinois-gorilla-baby-kidnapping-stupi...
# 2652  sequel-mockumentary-ghost-found footage-parano...
#
#                            poster_path                     backdrop_path  \
# 2624  /zXTM3qAXVYAYrhfYBpmescKMoes.jpg  /lh0uM88KjXsmRzWXUGAGWJ0AOJR.jpg
# 2627  /AnbLVdUEroTfHTUVAJCxkL4R0IH.jpg  /6JxJminJvYIVXbTakYJkbnga14P.jpg
# 2639  /vxwdArOG3R5AUHdvmwE4e7MLc0z.jpg  /rhFFbdRxSw25LvylJMbkOGljy2d.jpg
# 2644  /21U2jwl36hoTHsXB3fDuIQkcchu.jpg  /hq8dZfJEem1SIBCElMAuaJIfl6Q.jpg
# 2652   /mh7j7XlYWo82UnQGhsxcuyolzp.jpg  /1S6HTRZ8HwuIM8KVNOaycN5WxwX.jpg
#
#                                         recommendations
# 2624  26655-203534-224303-10859-594404-14846-11374-1...
# 2627  1688-1705-1685-871-31067-869-811-2161-11234-18...
# 2639  153917-84903-385152-1015622-1077670-118737-953...
# 2644  361751-29918-332-10631-12139-1634-17414-11011-...
# 2652  41436-227348-72571-82990-146301-23827-609972-4...

# %%
# prompt: save df dataframe to a file

import pandas as pd

# Assuming 'df' is your DataFrame
df.to_csv('movie_data_processed.csv', index=False)  # Save to current directory
# To save it to Google Drive:
# df.to_csv('/content/drive/My Drive/movie_data_processed.csv', index=False)

# %%
# prompt: quick sort not using library

def quick_sort(arr):
    if len(arr) < 2:
        return arr
    else:
        pivot = arr[0]
        less = [i for i in arr[1:] if i <= pivot]
        greater = [i for i in arr[1:] if i > pivot]
        return quick_sort(less) + [pivot] + quick_sort(greater)
